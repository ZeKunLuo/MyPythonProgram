# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
list_batch = []
list_loss = []
with open('loss_curve_DNN.txt') as f:
    for line in f.readlines():
        a = line.split()
        #print(a)
                
        list_loss.append(int(float(a[2][5:])))

# %%
list_batch = [i+1 for i in range(len(list_loss))]
print(len(list_batch))
plt.plot(list_batch,list_loss,label='Frist line',linewidth=3,color='r')
plt.xlabel('batch')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# 3000

# %%
list_batch = []
list_loss = []
list_loss_custom = []
with open('loss_curve_DRNN.txt') as f:
    for line in f.readlines():
        a = line.split()
        #print(a)
        list_loss.append(float(a[2][9:]))
    print()
with open('loss_curve_custom.txt') as f:
    for line in f.readlines():
        a = line.split()
        #print(a)
        list_loss_custom.append(float(a[2][9:]))
    print()

# %%
list_batch_custom = [i+1 for i in range(len(list_loss_custom))]
list_batch = [i+1 for i in range(len(list_loss))]
print(len(list_batch))
plt.plot(list_batch,list_loss_custom,label='DCNN',linewidth=1)
plt.plot(list_batch_custom,list_loss,label = 'DRCNN',linewidth=1)
plt.xlabel('eopoch')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# 1171

# %%
loss_DCNN = [2545.9635582910455,83.87751080200705,65.52513698708843,56.02997477121756
           ,52.719446995728454, 44.61447672881711, 42.0567081255812, 34.7620602735961, 
           35.52898284750925, 31.635601364495887, 33.9364363665522, 33.81547784563941, 29.757302958255924, 
           28.767904965600497,29.343354324243244]
loss_DRCNN = [1142.826662182808, 56.188454503744424, 46.53562422495493, 43.54785347236714, 
                38.5829726944507, 36.26038333259418, 34.031938753392495, 32.7271032719545, 
                33.87380114953283, 30.64993326544342, 
                30.742813974513975, 31.039232921379973, 30.386192912996655, 31.348936332573352,29.354932312354789]

# %%
import matplotlib.pyplot as plt
list_epochs_custom = [i+1 for i in range(len(loss_DCNN))]
list_epochs = [i+1 for i in range(len(loss_DRCNN))]
#print(len(list_batch))
plt.plot(list_epochs,loss_DCNN,label='DCNN',linewidth=1)
plt.plot(list_epochs,loss_DRCNN,label = 'DRCNN',linewidth=1)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
import cv2
import numpy as np
import os
path = 'E:\Download\Retinex_test\\'
p = os.listdir(path)
#img_1 = cv2.imread(path+p[0]+'\\3.png')
img_2 = cv2.imread(path+p[1]+'\\4.png')
img_3 = cv2.imread(path+p[3]+'\\4.png')
image = np.hstack([img_2,img_3])
cv2.imshow('high,low,re_image',image)
cv2.imwrite('E:\\Download\\Retinex_test\\merge\\4.png',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-10,10,0.1)
y = np.where(x<=0,0,x)
plt.plot(x,y,label='ReLU',color='r')
plt.legend()
plt.show()
